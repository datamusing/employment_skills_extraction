# %%
import pandas as pd

# %%
xx = pd.read_excel('../data/retail_sales_job_sample_5000_jobs_skills_field.xlsx')

# %%
xx.keys()
# Out:
# Index([u'JobID', u'RawJobTitle', u'RawJobText', u'CanonSkills', u'MinDegreeLevel', u'CanonCertification', u'MinExperience'], dtype='object')

# %% [markdown]
# Clean the text

# %%
text_list = []
for tt in xx.RawJobText:
     text_list +=[''.join(filter(lambda c: not c.isdigit(), tt))]

# %%
xx['JobTextnonumbers'] = text_list

# %%
import nltk

# %%
import numpy
import matplotlib.pyplot as plt
import nltk.stem
global english_stemmer 
english_stemmer = nltk.stem.SnowballStemmer('english')
from sklearn import decomposition
from sklearn.feature_extraction import text 
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
class StemmedTfidfVectorizer(TfidfVectorizer):
	
	def build_analyzer(self):
		analyzer = super(TfidfVectorizer, self).build_analyzer()
		return lambda doc: (english_stemmer.stem(w) for w in analyzer(doc))

# %%
stop_words = 'blah'
stop_words = text.ENGLISH_STOP_WORDS.union(stop_words)

# %%
vectorizer = TfidfVectorizer(min_df=0.001, max_df=3.0,stop_words = stop_words,ngram_range=(4,6))
vectorized = vectorizer.fit_transform(xx.JobTextnonumbers)
feature_names = vectorizer.get_feature_names()

# %%
feature_names
# Out:
# [u'__________________________________________________________________ additionally excellent interpersonal',
#  u'__________________________________________________________________ additionally excellent interpersonal organizational',
#  u'__________________________________________________________________ additionally excellent interpersonal organizational skills',
#  u'_ability earn year_ wireless',
#  u'_ability earn year_ wireless advantage',
#  u'_ability earn year_ wireless advantage premium',
#  u'_among responsibilities position involved',
#  u'_among responsibilities position involved following',
#  u'_among responsibilities position involved following activities',
#  u'_are ready exciting career',
#  u'_are ready exciting career fast',
#  u'_are ready exciting career fast moving',
#  u'_benefits privileges growth opportunities_',
#  u'_education currently enrolled high',
#  u'_education currently enrolled high school',
# ...

# %%
class StemmedTfidfVectorizer(TfidfVectorizer):
	
	def build_analyzer(self):
		analyzer = super(TfidfVectorizer, self).build_analyzer()
		return lambda doc: (english_stemmer.stem(w) for w in analyzer(doc))

# %%
vectorizer_new = TfidfVectorizer(min_df=0.1, max_df=1.0,stop_words = stop_words)
vectorized_new = vectorizer_new.fit_transform(xx.JobTextnonumbers)x
feature_names_new = vectorizer_new.get_feature_names()

# %%
n_topics=100
n_top_words = 10
nmf = decomposition.NMF(n_components = n_topics).fit(vectorized_new)
topic_new=[]
weight_all=[]
weight_mat=nmf.fit_transform(vectorized_new)
for topic_idx, topic in enumerate(nmf.components_):
    topic_new.append( " ".join([feature_names_new[i] \
        for i in topic.argsort()[:-n_top_words - 1:-1]]))
    weights = np.array( [topic[i] for i in topic.argsort()[:-n_top_words - 1:-1]])
    weight_all += [weights]
# Out:
# /usr/local/lib/python2.7/site-packages/sklearn/decomposition/nmf.py:539: UserWarning: Iteration limit reached during fit
#   warnings.warn("Iteration limit reached during fit")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-013707c8b53b> in <module>()
#       7 for topic_idx, topic in enumerate(nmf.components_):
#       8     topic_new.append( " ".join([feature_names_new[i]         for i in topic.argsort()[:-n_top_words - 1:-1]]))
# ----> 9     weights = np.array( [topic[i] for i in topic.argsort()[:-n_top_words - 1:-1]])
#      10     weight_all += [weights]
#
# NameError: name 'np' is not defined

# %%
topic_new
# Out:
# [u'sales goals selling commission associate successful monthly journals using environment']

# %%
import seaborn as sns
import numpy as np
# %pylab inline
pylab.hist(np.log(vectorized.sum(axis=0)[0].tolist()[0]))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['text']
# `%matplotlib` prevents importing * from pylab and numpy
# (array([  9379.,  22500.,  14987.,  10231.,   4604.,   4103.,   1200.,
#           1560.,   1311.,    643.]),
#  array([-2.21374776, -1.60726864, -1.00078953, -0.39431041,  0.21216871,
#          0.81864782,  1.42512694,  2.03160606,  2.63808517,  3.24456429,
#          3.8510434 ]),
#  <a list of 10 Patch objects>)

# %%
bag_n_grams = vectorized.sum(axis=0)[0].tolist()[0]

# %%
id= numpy.where(np.array(bag_n_grams)>1)
len(id[0])

# %%
id[0]

# %%
feature_names[14:20]

# %%
vectorized.shape, len(feature_names)

# %%
xx.
