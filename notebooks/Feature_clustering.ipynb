# %%
from sklearn.cluster import KMeans
# Out:
# /usr/lib/python2.7/dist-packages/scipy/spatial/__init__.py:88: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility
#   from .ckdtree import *
# /usr/lib/python2.7/dist-packages/scipy/spatial/__init__.py:89: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility
#   from .qhull import *
# /usr/lib/python2.7/dist-packages/scipy/stats/distributions.py:32: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility
#   from . import vonmises_cython
# /usr/lib/python2.7/dist-packages/scipy/stats/stats.py:251: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility
#   from ._rank import rankdata, tiecorrect

# %%
import pandas as pd
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/__init__.py:6: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility
#   from . import hashtable, tslib, lib
# /usr/local/lib/python2.7/dist-packages/pandas/core/common.py:17: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility
#   import pandas.algos as algos
# /usr/local/lib/python2.7/dist-packages/pandas/core/index.py:12: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility
#   import pandas.index as _index
# /usr/local/lib/python2.7/dist-packages/pandas/sparse/array.py:16: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility
#   from pandas._sparse import BlockIndex, IntIndex
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.py:26: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility
#   import pandas.parser as _parser
# /usr/local/lib/python2.7/dist-packages/pandas/io/packers.py:63: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility
#   from pandas.msgpack import Unpacker as _Unpacker, Packer as _Packer

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_extraction import text

# %%
import nltk.stem
global english_stemmer 
english_stemmer = nltk.stem.SnowballStemmer('english')
class StemmedCountVectorizer(CountVectorizer):
	
	def build_analyzer(self):
		analyzer = super(CountVectorizer, self).build_analyzer()
		return lambda doc: (english_stemmer.stem(w) for w in analyzer(doc))

# %%
skills = pd.read_csv('candidate_features.tsv')

# %%
skills.keys()
# Out:
# Index([u'feature'], dtype='object')

# %%
#stop_words = ['skill','skills','perform','deliver','ability','avail','experience','demonstrate'] 
stop_words = ['available','availability']               
stop_words = text.ENGLISH_STOP_WORDS.union(stop_words)
vectorizer = StemmedCountVectorizer(min_df=10, max_df=0.5,stop_words = stop_words)
vectorized = vectorizer.fit_transform(skills.feature)

# %%
num_clusters = 35
km = KMeans(n_clusters = num_clusters, init = 'k-means++', n_init = 1,verbose=1)
clustered = km.fit(vectorized)
predict = km.predict(vectorized)
# Out:
# Initialization complete
# Iteration  0, inertia 67876.000
# Iteration  1, inertia 49752.900
# Iteration  2, inertia 49557.460
# Iteration  3, inertia 49446.451
# Iteration  4, inertia 49430.333
# Iteration  5, inertia 49418.839
# Iteration  6, inertia 49415.380
# Iteration  7, inertia 49414.776
# Iteration  8, inertia 49412.865
# Iteration  9, inertia 49412.579
# Iteration 10, inertia 49412.551
# Iteration 11, inertia 49412.549
# Converged at iteration 11

# %%
vectorizer.get_feature_names()
# Out:
# [u'000',
#  u'10',
#  u'12',
#  u'24',
#  u'25',
#  u'40',
#  u'50',
#  u'63',
#  u'_educ',
#  u'_essenti',
#  u'aa',
#  u'abil',
#  u'abl',
#  u'absent',
#  u'academ',
#  u'accept',
#  u'access',
#  u'accessori',
#  u'accid',
#  u'accommod',
#  u'accomplish',
#  u'accord',
#  u'account',
#  u'accur',
#  u'accuraci',
#  u'achiev',
#  u'acknowledg',
#  u'acquir',
#  u'acquisit',
#  u'act',
#  u'action',
#  u'activ',
#  u'ad',
#  u'adapt',
#  u'addit',
#  u'adher',
#  u'adjust',
#  u'administr',
#  u'adopt',
#  u'advanc',
#  u'advertis',
#  u'advic',
#  u'advisor',
#  u'afford',
#  u'age',
#  u'agenc',
#  u'agent',
#  u'aid',
#  u'alloc',
#  u'allow',
#  u'america',
#  u'analys',
#  u'analysi',
#  u'analyst',
#  u'analyt',
#  u'analyz',
#  u'apparel',
#  u'appear',
#  u'appl',
#  u'appli',
#  u'applic',
#  u'appoint',
#  u'approach',
#  u'appropri',
#  u'approxim',
#  u'aptitud',
#  u'area',
#  u'arm',
#  u'ascertain',
#  u'aspect',
#  u'assess',
#  u'asset',
#  u'assign',
#  u'assist',
#  u'associ',
#  u'attain',
#  u'attend',
#  u'attent',
#  u'attitud',
#  u'attract',
#  u'author',
#  u'auto',
#  u'automot',
#  u'avail',
#  u'awar',
#  u'ba',
#  u'bachelor',
#  u'background',
#  u'balanc',
#  u'bank',
#  u'base',
#  u'basi',
#  u'basic',
#  u'behavior',
#  u'bend',
#  u'benefit',
#  u'best',
#  u'bi',
#  u'bid',
#  u'bilingu',
#  u'blue',
#  u'board',
#  u'bonus',
#  u'book',
#  u'branch',
#  u'brand',
#  u'bring',
#  u'broad',
#  u'bs',
#  u'budget',
#  u'build',
#  u'busi',
#  u'buy',
#  u'buyer',
#  u'ca',
#  u'cabl',
#  u'calcul',
#  u'california',
#  u'call',
#  u'candid',
#  u'capabl',
#  u'card',
#  u'care',
#  u'career',
#  u'carri',
#  u'case',
#  u'cash',
#  u'cashier',
#  u'categori',
#  u'center',
#  u'certain',
#  u'certif',
#  u'certifi',
#  u'champion',
#  u'chang',
#  u'channel',
#  u'charit',
#  u'check',
#  u'chemic',
#  u'claim',
#  u'class',
#  u'clean',
#  u'clear',
#  u'clearanc',
#  u'cleric',
#  u'click',
#  u'client',
#  u'clinic',
#  u'close',
#  u'coach',
#  u'coachabl',
#  u'cold',
#  u'collabor',
#  u'collect',
#  u'colleg',
#  u'com',
#  u'combin',
#  u'comfort',
#  u'commiss',
#  u'commit',
#  u'communic',
#  u'communiti',
#  u'commut',
#  u'compani',
#  u'compar',
#  u'compel',
#  u'compens',
#  u'compet',
#  u'competit',
#  u'competitor',
#  u'complet',
#  u'complex',
#  u'complianc',
#  u'comprehens',
#  u'comput',
#  u'concept',
#  u'concern',
#  u'concert',
#  u'concret',
#  u'condit',
#  u'conduct',
#  u'confid',
#  u'confidenti',
#  u'conflict',
#  u'connect',
#  u'consider',
#  u'consist',
#  u'construct',
#  u'consult',
#  u'consum',
#  u'contact',
#  u'content',
#  u'continu',
#  u'contract',
#  u'contribut',
#  u'control',
#  u'convent',
#  u'cooki',
#  u'coordin',
#  u'core',
#  u'corpor',
#  u'correct',
#  u'cosmet',
#  u'cost',
#  u'counsel',
#  u'counselor',
#  u'counter',
#  u'cours',
#  u'courteous',
#  u'cover',
#  u'coverag',
#  u'creat',
#  u'creativ',
#  u'credit',
#  u'critic',
#  u'cross',
#  u'cultur',
#  u'current',
#  u'custom',
#  u'cycl',
#  u'daili',
#  u'data',
#  u'databas',
#  u'date',
#  u'day',
#  u'deadlin',
#  u'deal',
#  u'dealership',
#  u'decis',
#  u'dedic',
#  u'deep',
#  u'degre',
#  u'degreecategoryretailjob',
#  u'deliv',
#  u'deliver',
#  u'deliveri',
#  u'demand',
#  u'demonstr',
#  u'depart',
#  u'depend',
#  u'depth',
#  u'descript',
#  u'design',
#  u'desir',
#  u'detail',
#  u'determin',
#  u'develop',
#  u'devic',
#  u'differ',
#  u'digit',
#  u'diploma',
#  u'direct',
#  u'disabl',
#  u'disciplin',
#  u'discount',
#  u'discuss',
#  u'display',
#  u'dispos',
#  u'distribut',
#  u'divers',
#  u'divis',
#  u'document',
#  u'dot',
#  u'drive',
#  u'driven',
#  u'driver',
#  u'drug',
#  u'dsd',
#  u'durabl',
#  u'duti',
#  u'easili',
#  u'educ',
#  u'educationhigh',
#  u'eeo',
#  u'effect',
#  u'effici',
#  u'effort',
#  u'electr',
#  u'electron',
#  u'elig',
#  u'email',
#  u'employ',
#  u'employe',
#  u'enabl',
#  u'end',
#  u'energet',
#  u'energi',
#  u'engag',
#  u'engin',
#  u'english',
#  u'enhanc',
#  u'enjoy',
#  u'enrol',
#  u'ensur',
#  u'enthusiasm',
#  u'entri',
#  u'environ',
#  u'environment',
#  u'eoe',
#  u'equip',
#  u'equit',
#  u'equival',
#  u'essenti',
#  u'est',
#  u'establish',
#  u'estat',
#  u'et',
#  u'ethic',
#  u'evalu',
#  u'even',
#  u'event',
#  u'exampl',
#  u'exceed',
#  u'excel',
#  u'except',
#  u'exchang',
#  u'excit',
#  u'execut',
#  u'exemplari',
#  u'exhibit',
#  u'expand',
#  u'expect',
#  u'expens',
#  u'experi',
#  u'expert',
#  u'expertis',
#  u'explain',
#  u'exposur',
#  u'extens',
#  u'extern',
#  u'extrem',
#  u'eye',
#  u'face',
#  u'facilit',
#  u'fair',
#  u'famili',
#  u'familiar',
#  u'fashion',
#  u'fast',
#  u'favor',
#  u'fa\xe7on',
#  u'featur',
#  u'feder',
#  u'fee',
#  u'feedback',
#  u'feel',
#  u'femal',
#  u'fiabl',
#  u'field',
#  u'file',
#  u'fill',
#  u'financ',
#  u'financi',
#  u'finra',
#  u'fit',
#  u'fix',
#  u'fixtur',
#  u'flexibl',
#  u'floor',
#  u'focus',
#  u'follow',
#  u'food',
#  u'foodservic',
#  u'footwear',
#  u'forecast',
#  u'foreign',
#  u'forklift',
#  u'formal',
#  u'formula',
#  u'foundat',
#  u'fragranc',
#  u'free',
#  u'frequent',
#  u'fresh',
#  u'friend',
#  u'fulli',
#  u'fun',
#  u'function',
#  u'fundament',
#  u'gain',
#  u'game',
#  u'ged',
#  u'general',
#  u'generat',
#  u'genuin',
#  u'gift',
#  u'given',
#  u'goal',
#  u'good',
#  u'graduat',
#  u'graph',
#  u'great',
#  u'greet',
#  u'grow',
#  u'growth',
#  u'gs',
#  u'guard',
#  u'guest',
#  u'guidanc',
#  u'guidelin',
#  u'hand',
#  u'handl',
#  u'health',
#  u'healthcar',
#  u'hear',
#  u'held',
#  u'help',
#  u'high',
#  u'higher',
#  u'hill',
#  u'hire',
#  u'histori',
#  u'hold',
#  u'holiday',
#  u'home',
#  u'honor',
#  u'hospit',
#  u'hour',
#  u'hous',
#  u'housekeep',
#  u'hs',
#  u'http',
#  u'hvac',
#  u'id',
#  u'ideal',
#  u'identifi',
#  u'imag',
#  u'immedi',
#  u'impact',
#  u'implement',
#  u'improv',
#  u'incent',
#  u'incident',
#  u'includ',
#  u'increas',
#  u'independ',
#  u'indic',
#  u'individu',
#  u'industri',
#  u'influenc',
#  u'inform',
#  u'infus',
#  u'initi',
#  u'innov',
#  u'insight',
#  u'inspect',
#  u'inspir',
#  u'instal',
#  u'institut',
#  u'instruct',
#  u'insur',
#  u'integr',
#  u'intellig',
#  u'interact',
#  u'interior',
#  u'intermedi',
#  u'intern',
#  u'internet',
#  u'internship',
#  u'interperson',
#  u'interpret',
#  u'inventori',
#  u'invest',
#  u'issu',
#  u'item',
#  u'jewelri',
#  u'job',
#  u'key',
#  u'knowledg',
#  u'la',
#  u'languag',
#  u'law',
#  u'lbs',
#  u'lead',
#  u'leader',
#  u'leadership',
#  u'lean',
#  u'learn',
#  u'legal',
#  u'level',
#  u'leverag',
#  u'li',
#  u'licens',
#  u'license',
#  u'licensur',
#  u'life',
#  u'lift',
#  u'light',
#  u'like',
#  u'limit',
#  u'line',
#  u'lingualeduc',
#  u'list',
#  u'listen',
#  u'liter',
#  u'live',
#  u'll',
#  u'loan',
#  u'local',
#  u'locat',
#  u'logic',
#  u'long',
#  u'luxuri',
#  u'maci',
#  u'maintain',
#  u'mainten',
#  u'make',
#  u'manag',
#  u'manner',
#  u'manufactur',
#  u'market',
#  u'marketplac',
#  u'match',
#  u'materi',
#  u'math',
#  u'mathemat',
#  u'maxim',
#  u'mcgraw',
#  u'measur',
#  u'mechan',
#  u'medic',
#  u'meet',
#  u'member',
#  u'memor',
#  u'memori',
#  u'mental',
#  u'merchandis',
#  u'method',
#  u'metric',
#  u'microsoft',
#  u'militari',
#  u'mind',
#  u'minimum',
#  u'minor',
#  u'model',
#  u'modul',
#  u'moment',
#  u'monday',
#  u'monitor',
#  u'month',
#  u'mortgag',
#  u'motiv',
#  u'ms',
#  u'multi',
#  u'multifamili',
#  u'multipl',
#  u'multitask',
#  u'nation',
#  u'navig',
#  u'neat',
#  u'necessari',
#  u'need',
#  u'negoti',
#  u'network',
#  u'new',
#  u'non',
#  u'normal',
#  u'note',
#  u'nurs',
#  u'nys',
#  u'object',
#  u'objection',
#  u'obtain',
#  u'occasion',
#  u'offer',
#  u'offic',
#  u'older',
#  u'ongo',
#  u'onlin',
#  u'open',
#  u'oper',
#  u'opportun',
#  u'optim',
#  u'option',
#  u'oracl',
#  u'oral',
#  u'order',
#  u'organ',
#  u'organiz',
#  u'orient',
#  u'origin',
#  u'outdoor',
#  u'outgo',
#  u'outlook',
#  u'outsid',
#  u'outstand',
#  u'overal',
#  u'overtim',
#  u'ownership',
#  u'pace',
#  u'paid',
#  u'park',
#  u'part',
#  u'particip',
#  u'partner',
#  u'pass',
#  u'passion',
#  u'past',
#  u'patient',
#  u'pay',
#  u'payabl',
#  u'payment',
#  u'pc',
#  u'pcm',
#  u'peopl',
#  u'percentag',
#  u'perform',
#  u'period',
#  u'perish',
#  u'person',
#  u'personnel',
#  u'persuas',
#  u'pharmaci',
#  u'pharmacolog',
#  u'phone',
#  u'physic',
#  u'physician',
#  u'pivot',
#  u'plan',
#  u'platform',
#  u'player',
#  u'plus',
#  u'point',
#  u'polici',
#  u'portabl',
#  u'portfolio',
#  u'pos',
#  u'posit',
#  u'possess',
#  u'possibl',
#  u'post',
#  u'pound',
#  u'power',
#  u'powerpoint',
#  u'practic',
#  u'pre',
#  u'prefer',
#  u'prepar',
#  u'presenc',
#  u'present',
#  u'pressur',
#  u'prevent',
#  u'previous',
#  u'price',
#  u'primari',
#  u'principl',
#  u'prior',
#  u'priorit',
#  u'prioriti',
#  u'proactiv',
#  u'problem',
#  u'procedur',
#  u'process',
#  u'produc',
#  u'product',
#  u'profession',
#  u'profici',
#  u'profil',
#  u'profit',
#  u'program',
#  u'progress',
#  u'project',
#  u'promot',
#  u'prompt',
#  u'proof',
#  u'proper',
#  u'proposit',
#  u'prospect',
#  u'protect',
#  u'prove',
#  u'proven',
#  u'provid',
#  u'public',
#  u'purchas',
#  u'purpos',
#  u'qualif',
#  u'qualifi',
#  u'qualificationseduc',
#  u'qualiti',
#  u'quantit',
#  u'question',
#  u'quick',
#  u'quota',
#  u'rang',
#  u'rate',
#  u'reach',
#  u'read',
#  u'real',
#  u'reason',
#  u'receiv',
#  u'recent',
#  u'reciproc',
#  u'recogn',
#  u'recommend',
#  u'record',
#  u'recruit',
#  u'refer',
#  u'referr',
#  u'regard',
#  u'region',
#  u'regist',
#  u'registr',
#  u'regul',
#  u'regular',
#  u'regulatori',
#  u'rehabilit',
#  u'reimburs',
#  u'relat',
#  u'relationship',
#  u'relev',
#  u'reliabl',
#  u'reloc',
#  u'remain',
#  u'remark',
#  u'renew',
#  u'repair',
#  u'repeat',
#  u'repetit',
#  u'report',
#  u'request',
#  u'requir',
#  u'requisit',
#  u'research',
#  u'resolv',
#  u'resourc',
#  u'respiratori',
#  u'respond',
#  u'respons',
#  u'result',
#  u'retail',
#  u'retir',
#  u'revenu',
#  u'review',
#  u'reward',
#  u'right',
#  u'rn',
#  u'role',
#  u'rotat',
#  u'routin',
#  u'safe',
#  u'safeti',
#  u'salari',
#  u'sale',
#  u'saleseduc',
#  u'salesforc',
#  u'salon',
#  u'satisfactorili',
#  u'saturday',
#  u'scalabl',
#  u'schedul',
#  u'school',
#  u'scienc',
#  u'season',
#  u'secondari',
#  u'secur',
#  u'securit',
#  u'seek',
#  u'select',
#  u'self',
#  u'sell',
#  u'seminar',
#  u'seri',
#  u'serv',
#  u'servic',
#  u'servsaf',
#  u'set',
#  u'share',
#  u'shelv',
#  u'shield',
#  u'shift',
#  u'shop',
#  u'show',
#  u'similar',
#  u'simpl',
#  u'site',
#  u'situat',
#  u'skill',
#  u'smart',
#  u'social',
#  u'softwar',
#  u'solid',
#  u'solut',
#  u'solv',
#  u'sound',
#  u'spanish',
#  u'speak',
#  u'special',
#  u'specialist',
#  u'specialti',
#  u'specif',
#  u'sport',
#  u'stabl',
#  u'staff',
#  u'stand',
#  u'standard',
#  u'state',
#  u'status',
#  u'step',
#  u'stock',
#  u'store',
#  u'strateg',
#  u'strategi',
#  u'stress',
#  u'strong',
#  u'structur',
#  u'student',
#  u'style',
#  u'subject',
#  u'success',
#  u'suffici',
#  u'suggest',
#  u'suit',
#  u'suitabl',
#  u'summari',
#  u'sunday',
#  u'superior',
#  u'supervis',
#  u'supervisori',
#  u'suppli',
#  u'support',
#  u'surgic',
#  u'sustain',
#  u'system',
#  u'tabl',
#  u'tablet',
#  u'take',
#  u'talent',
#  u'target',
#  u'task',
#  u'teach',
#  u'team',
#  u'teamwork',
#  u'tech',
#  u'technic',
#  u'techniqu',
#  u'technolog',
#  u'telephon',
#  u'termin',
#  u'territori',
#  u'test',
#  u'think',
#  u'thorough',
#  u'tiffani',
#  u'time',
#  u'timeshar',
#  u'tool',
#  u'track',
#  u'train',
#  u'transact',
#  u'transfer',
#  u'translat',
#  u'transport',
#  u'travel',
#  u'treasuri',
#  u'trend',
#  u'troubleshoot',
#  u'truck',
#  u'trust',
#  u'type',
#  u'typic',
#  u'unabl',
#  u'unavail',
#  u'understand',
#  u'underwrit',
#  u'unforgett',
#  u'uniqu',
#  u'unit',
#  u'univers',
#  u'unparallel',
#  u'unrestrict',
#  u'updat',
#  u'use',
#  u'user',
#  u'util',
#  u'vacat',
#  u'valid',
#  u'valu',
#  u'valuabl',
#  u'variabl',
#  u'varieti',
#  u'various',
#  u'vehicl',
#  u'vendor',
#  u'verbal',
#  u'verif',
#  u'verifi',
#  u'vet',
#  u'veteran',
#  u'viabl',
#  u'view',
#  u'vision',
#  u'visit',
#  u'visual',
#  u'vocat',
#  u'warner',
#  u'web',
#  u'websit',
#  u'week',
#  u'weekend',
#  u'welcom',
#  u'wholesal',
#  u'will',
#  u'willing',
#  u'window',
#  u'wine',
#  u'wireless',
#  u'women',
#  u'word',
#  u'work',
#  u'workabl',
#  u'workforc',
#  u'workshop',
#  u'world',
#  u'write',
#  u'written',
#  u'www',
#  u'wyndham',
#  u'year',
#  u'yrs']

# %%
skills
#vectorized[0].todense()
# Out:
#                                             feature  cluster
# 0                                        ability to        0
# 1                                      knowledge of        4
# 2                                           able to       19
# 3                                   ability to work        0
# 4                              communication skills        0
# 5                                           be able       19
# 6                                        be able to       19
# 7                               customer experience        0
# 8                                     knowledge and        4
# 9                                  sales experience        0
# 10                                product knowledge       10
# 11                                    perform other        0
# 12                             perform other duties        0
# 13                                     must be able       19
# 14                          perform other duties as        0
# 15                                  must be able to       19
# 16                              mathematical skills        0
# 17                                  ability to read        0
# 18                                     knowledge to        4
# 19                                    available for        8
# 20                               available for this        8
# 21                      available for this position        8
# 22                                  work experience        0
# 23                                   education high       11
# 24                            education high school       11
# 25                    education high school diploma       11
# 26                                       and skills        0
# 27                             knowledge and skills        4
# 28                        oral communication skills        0
# 29                               ability to perform        0
# ...                                             ...      ...
# 32536                            ability to clearly        0
# 32537                             able to climb and       19
# 32538                     able to communicate these       19
# 32539                       able to communicate the       19
# 32540            through minimum banking experience        0
# 32541                  products excellent knowledge       10
# 32542                 ability to clearly understand        0
# 32543                            products knowledge       10
# 32544              products knowledge understanding       10
# 32545          professionally automotive experience        0
# 32546  professionalism maintaining strong knowledge        4
# 32547                proficiency of computer skills        0
# 32548          professional standard and applicable       16
# 32549            proficiency second language skills        0
# 32550                      able to clearly document       19
# 32551                       able to clearly expound       19
# 32552                       this role only suitable        0
# 32553               professionals have knowledge to        4
# 32554                  professionals have knowledge        4
# 32555      professional skills education experience       11
# 32556    professional toronto opportunity available        8
# 32557              professional years of experience        0
# 32558                             able to coach and       19
# 32559                      professional who is able       19
# 32560                                 able to coach       19
# 32561               ability to communicate business        0
# 32562                      able to climb anddescend       19
# 32563            professional with strong knowledge        4
# 32564            professional with years experience        0
# 32565                            00 for pre license       18
#
# [32566 rows x 2 columns]

# %%
len(predict)
# Out:
# 32566

# %%
vectorized.shape
# Out:
# (32566, 919)

# %%
len(skills.feature)
# Out:
# 32566

# %%
skills['cluster'] = predict

# %%
skills[skills['cluster'] == 6]
# Out:
#                                                 feature  cluster
# 1                                          knowledge of        6
# 8                                         knowledge and        6
# 10                                    product knowledge        6
# 18                                         knowledge to        6
# 27                                 knowledge and skills        6
# 37                       knowledge and skills effective        6
# 38                                  necessary knowledge        6
# 39                       necessary knowledge and skills        6
# 41                              necessary knowledge and        6
# 42                                guidance knowledge of        6
# 43                      presentation guidance knowledge        6
# 44                                   guidance knowledge        6
# 45                                   knowledge of basic        6
# 50                             when necessary knowledge        6
# 52                                 product knowledge to        6
# 80                                     strong knowledge        6
# 85                                  strong knowledge of        6
# 88                                     knowledge of all        6
# 89                                maintain knowledge of        6
# 90                                   maintain knowledge        6
# 93                            maintain strong knowledge        6
# 98                             knowledge of competitive        6
# 99                         maintain strong knowledge of        6
# 103                           knowledge of all products        6
# 112                         features maintain knowledge        6
# 118                               product knowledge and        6
# 139                                  knowledge of store        6
# 144                              knowledge and business        6
# 145                             other product knowledge        6
# 146                      product knowledge and business        6
# ...                                                 ...      ...
# 32414                        through complete knowledge        6
# 32435                   products and services knowledge        6
# 32442                     through product knowledge key        6
# 32445          product knowledge leadership development        6
# 32458                    process gain broader knowledge        6
# 32459                   to continually expand knowledge        6
# 32465                            tire knowledge and how        6
# 32466              professional and technical knowledge        6
# 32476                      product knowledge leadership        6
# 32484                   products excellent knowledge of        6
# 32486                     thorough knowledge of overall        6
# 32487               products knowledge understanding of        6
# 32488               professional knowledge dealing with        6
# 32490                  those results business knowledge        6
# 32491                 thorough knowledge of silhouettes        6
# 32498                 this requires extensive knowledge        6
# 32505                    professional knowledge dealing        6
# 32509  professional sensitive knowledgeable resourceful        6
# 32513                     thorough knowledge of company        6
# 32514                         thorough knowledge of and        6
# 32515              professional sensitive knowledgeable        6
# 32525                   proficiency including knowledge        6
# 32526                proficiency including knowledge of        6
# 32541                      products excellent knowledge        6
# 32543                                products knowledge        6
# 32544                  products knowledge understanding        6
# 32546      professionalism maintaining strong knowledge        6
# 32553                   professionals have knowledge to        6
# 32554                      professionals have knowledge        6
# 32563                professional with strong knowledge        6
#
# [5199 rows x 2 columns]

# %%
skills.sort('cluster')
# Out:
#                                          feature  cluster
# 29657                    demonstrated verifiable        0
# 30159      skills demonstrated leadership skills        0
# 30158  skills demonstrated leadership experience        0
# 7419                          demonstrated sales        0
# 7417                    demonstrates exceptional        0
# 7412                         demonstrated verbal        0
# 7407                        demonstrates success        0
# 2916                     demonstrates values and        0
# 7403                    demonstrates proficiency        0
# 1101                demonstrated success working        0
# 6929          demonstrating magic selling skills        0
# 10963          are accountable for demonstrating        0
# 18789                     and demonstrated skill        0
# 7342                        demonstrates product        0
# 16439             brings demonstrated experience        0
# 29967       demonstrated strong and professional        0
# 29966                    demonstrated strong and        0
# 29964            demonstrated proficiency in one        0
# 29963      demonstrated proficiency in microsoft        0
# 29962    demonstrated professional reception and        0
# 29961              demonstrated oral and written        0
# 18743      if applicable demonstrates compliance        0
# 30160                 skills demonstrates skills        0
# 30161   solutions demonstrated consulting skills        0
# 30205               skills demonstrable conflict        0
# 7442                        demonstrated through        0
# 27852            demonstrated computer skills to        0
# 27854       demonstrated commitment to excellent        0
# 27855                 demonstrated commitment to        0
# 27856      demonstrated analytical communication        0
# ...                                          ...      ...
# 30499                         sales targets able       19
# 11036                ability to achieve targeted       19
# 23102             achieve target some experience       19
# 7636                              are targetable       19
# 8574                         that are targetable       19
# 10462          delivering required sales targets       19
# 30259             solutions applicable to target       19
# 11587                      perform at the target       19
# 8542           targets qualifications experience       19
# 8646                           targetable by the       19
# 12014                       applicable to target       19
# 30667                    ability to meet targets       19
# 10803               networks that are targetable       19
# 8698                           are targetable by       19
# 2861                    targets where applicable       19
# 11337                 targetable by the training       19
# 14287                 company sales targets able       19
# 11455                     that are targetable by       19
# 3099              sales targets where applicable       19
# 9502     sales targets qualifications experience       19
# 7461                               targetable by       19
# 30464                   sales targets experience       19
# 30463                     sales targets able and       19
# 24028                     target some experience       19
# 24110                   targets able and willing       19
# 24109                         targets experience       19
# 29730                deliver to clients targeted       19
# 3101              targets where applicable offer       19
# 15979          carrying sales targets experience       19
# 11989                applicable to target market       19
#
# [32566 rows x 2 columns]

# %%
gg = skills.groupby('cluster')

# %%
import collections, re, operator
def BagofWords(textlist):
    bagsofwords = [ collections.Counter(re.findall(r'\w+', txt))
            for txt in textlist]
    words=Counter()
    for bbb in bagsofwords:
        for bb,v in bbb.iteritems():  
            words[bb]+=v
    sorted_words = sorted(words.iteritems(), key=operator.itemgetter(1),reverse=True)
    return sorted_words

# %%
from collections import defaultdict
d=defaultdict()
key=set(predict)
for k in key:
    d[k]=[]
for x,y in gg:
    d[x]+=list(y.feature.values)
    print y.feature.values
# Out:
# ['perform other' 'perform other duties' 'perform other duties as' ...,
#  'professional licensure' 'professional demeanor and appearanceeducation'
#  'this role only suitable']
# ['education high' 'education high school' 'education high school diploma'
#  ..., 'professional development performance education' 'products education'
#  'products education and']
# ['demonstrated ability' 'demonstrated ability to' 'demonstrate knowledge'
#  'demonstrate knowledge of' 'demonstrate knowledge of store'
#  'demonstrate commitment' 'demonstrate commitment and'
#  'procedures demonstrate knowledge'
#  'demonstrated communication and interpersonal'
#  'demonstrated communication' 'demonstrated communication and'
#  'demonstrated ability to develop' 'demonstrate high'
#  'demonstrate excellent' 'demonstrate high degree' 'demonstrates an'
#  'demonstrate excellent customer' 'demonstrate passion'
#  'demonstrate passion for' 'demonstrate an' 'demonstrate passion for the'
#  'factors demonstrate knowledge' 'demonstrates passion for'
#  'demonstrates passion' 'demonstrate superior'
#  'demonstrate superior product knowledge' 'demonstrate superior product'
#  'demonstrate strong' 'demonstrates an energetic' 'demonstrate the'
#  'demonstrating superior product knowledge' 'ability to demonstrate'
#  'demonstrate product' 'demonstrate an enthusiastic'
#  'demonstrate an enthusiastic and' 'ability to demonstrate strong'
#  'demonstrate product knowledge' 'priority demonstrate knowledge'
#  'demonstrate strong guest' 'demonstrate high level'
#  'demonstrate knowledge of bedding' 'perform food demonstrations'
#  'perform food demonstrations are' 'demonstrate strong customer'
#  'clients demonstrate knowledge' 'with clients demonstrate knowledge'
#  'demonstrate the company core' 'clients demonstrate knowledge of'
#  'demonstrate the company' 'demonstrate excellent selling skills'
#  'demonstrate working' 'demonstrate working knowledge of'
#  'and demonstrate working knowledge' 'demonstrate excellent selling'
#  'demonstrate working knowledge' 'demonstrates an inspirational'
#  'demonstrates willingness' 'demonstrated customer'
#  'demonstrates willingness to' 'demonstrated track'
#  'demonstrated track record' 'demonstrated track record of'
#  'demonstrate an energetic' 'demonstrate an entrepreneurial'
#  'demonstrate effective' 'file demonstrate knowledge'
#  'demonstrate commitment to' 'demonstrate consultative sales'
#  'demonstrates the' 'demonstrate consultative' 'demonstrate professional'
#  'demonstrate effective written' 'demonstrates an understanding'
#  'demonstrate professional image' 'demonstrate thorough'
#  'demonstrates customer' 'demonstrates advanced' 'demonstrates commitment'
#  'demonstrate asset' 'demonstrates empowerment' 'demonstrated skills'
#  'demonstrate in' 'demonstrates empowerment to ensure'
#  'demonstrates commitment to' 'demonstrate in depth knowledge'
#  'demonstrate asset protection awareness'
#  'demonstrate an entrepreneurial spirit' 'demonstrate in depth'
#  'demonstrated skills in' 'demonstrates empowerment to'
#  'demonstrate asset protection' 'demonstrate customer first'
#  'demonstrate honesty and' 'demonstrate thorough knowledge'
#  'demonstrate the ability' 'demonstrate strong understanding'
#  'book demonstrate knowledge' 'demonstrates values and'
#  'demonstrates awareness of' 'demonstrate solid product'
#  'demonstrates values and behaviors' 'demonstrate thorough knowledge of'
#  'demonstrate commitment to satisfying'
#  'business demonstrate thorough knowledge'
#  'client book demonstrate knowledge' 'demonstrate strong understanding of'
#  'demonstrate solid product knowledge' 'book demonstrate knowledge of'
#  'demonstrate honesty and integrity' 'demonstrate the ability to'
#  'demonstrates values' 'demonstrates awareness' 'demonstrate solid'
#  'demonstrated knowledge' 'demonstrate honesty' 'demonstrate customer'
#  'performance expectations demonstrate' 'demonstrate initiative in'
#  'demonstrate initiative in learning' 'demonstrated ability to work'
#  'performance expectations demonstrate knowledge' 'demonstrates strong'
#  'demonstrated results' 'demonstrated outside'
#  'demonstrates commitment to simply' 'demonstrated leadership'
#  'demonstrates the power of' 'demonstrate and' 'demonstrate new'
#  'demonstrated strong' 'demonstrated results in'
#  'expectations demonstrate knowledge' 'demonstrate initiative'
#  'demonstrated outside sales' 'demonstrate customer first mindset'
#  'expectations demonstrate knowledge of' 'demonstrated knowledge of'
#  'demonstrates the power' 'performance with demonstrated results'
#  'demonstrated proficiency' 'demonstrated child' 'demonstrate suggestive'
#  'demonstrates functional' 'demonstrate how' 'demonstrate sound'
#  'demonstrate no' 'demonstrate no problem' 'demonstrate new and'
#  'demonstrate suggestive selling' 'demonstrate strong verbal'
#  'demonstrate excellent communication' 'demonstrates functional and'
#  'demonstrated results in achieving' 'demonstrates functional and or'
#  'demonstrate suggestive selling and' 'demonstrate the adoption first'
#  'demonstrates advanced technical' 'demonstrates advanced technical skills'
#  'demonstrate excellent communication and' 'demonstrate strong verbal and'
#  'demonstrate no problem attitude' 'demonstrate new and used'
#  'demonstrate an entrepreneurial approach' 'performance with demonstrated'
#  'demonstrate the adoption' 'demonstrated child welfare'
#  'demonstrates open' 'demonstrates comprehensive' 'demonstrates high'
#  'demonstrated proficiency in' 'demonstrates open approachable'
#  'demonstrate company standards' 'demonstrated excellence in'
#  'demonstrate adherence to' 'demonstrate an understanding'
#  'demonstrate sales leadership' 'demonstrate flexibility and'
#  'demonstrate sense of' 'demonstrate foundational understanding'
#  'demonstrate fundamental knowledge' 'demonstrate good judgment'
#  'demonstrate stable and' 'demonstrate the client'
#  'demonstrates advanced knowledge' 'asset demonstrate stable'
#  'demonstrate flexibility and have' 'demonstrate fundamental knowledge of'
#  'demonstrate foundational understanding of'
#  'demonstrate company standards in' 'an asset demonstrate stable'
#  'demonstrates open approachable and'
#  'and demonstrate fundamental knowledge'
#  'demonstrates advanced knowledge of' 'demonstrate the client fiber'
#  'demonstrate stable and committed' 'demonstrate sales leadership and'
#  'demonstrate sense of urgency' 'demonstrated excellence in selling'
#  'associate demonstrates open approachable'
#  'demonstrated ability to navigate' 'demonstrated ability to coach'
#  'asset demonstrate stable and' 'demonstrated ability to take'
#  'demonstrate adherence' 'demonstrate to' 'demonstrate products'
#  'demonstrated computer' 'demonstrate foundational'
#  'demonstrate fundamental' 'demonstrate company' 'demonstrate good'
#  'demonstrated analytical' 'demonstrate flexibility' 'demonstrate our'
#  'demonstrate willingness' 'demonstrate leadership'
#  'demonstrated excellence' 'demonstrate empathy' 'demonstrate sense'
#  'demonstrate sales' 'demonstrate stable'
#  'demonstrating magic selling skills' 'demonstrate feasibility'
#  'demonstrate expert' 'demonstrated through our' 'demonstrate features'
#  'demonstrate complete' 'demonstrate eddie' 'demonstrate basic'
#  'demonstrate behaviours' 'demonstrate open' 'demonstrate intermediate'
#  'demonstrates product' 'demonstrate use' 'demonstrate training'
#  'demonstrates proficiency' 'demonstrated verbal'
#  'demonstrates exceptional' 'demonstrated sales' 'demonstrated through'
#  'demonstrates consistent' 'demonstrate problem' 'demonstrates desire'
#  'skills demonstrable' 'demonstrate self' 'demonstrates understanding'
#  'demonstrated organizational' 'demonstrate full' 'performance demonstrate'
#  'demonstrated comfort' 'demonstrated performance' 'demonstrate teamwork'
#  'demonstrates technical' 'demonstrated problem' 'demonstrating knowledge'
#  'knowledge and demonstrate' 'performance demonstrate an'
#  'knowledge and demonstrated' 'demonstrates high quality'
#  'demonstrates customer engagement' 'demonstrates consistent sales'
#  'demonstrates desire to' 'demonstrating sales skills'
#  'demonstrates comprehensive understanding' 'demonstrates the ability'
#  'demonstrates strong customer' 'demonstrating knowledge of'
#  'demonstrates understanding of' 'demonstrates technical expertise'
#  'demonstrates proficiency in' 'shop demonstrate knowledge'
#  'demonstrate sound judgment' 'demonstrate strong organizational'
#  'demonstrate intermediate to' 'demonstrate our quality'
#  'demonstrate complete knowledge' 'demonstrate an in'
#  'competencies demonstrated knowledge' 'companies demonstrated skills'
#  'demonstrate an established' 'demonstrate problem solving'
#  'demonstrate behaviours that' 'demonstrate basic selling'
#  'demonstrate effective phone' 'demonstrate expert knowledge'
#  'demonstrate how new' 'demonstrate high degrees'
#  'demonstrate feasibility of' 'demonstrate features and'
#  'demonstrate eddie bauer' 'demonstrate open approachable'
#  'demonstrate and practice' 'demonstrated strong negotiation'
#  'demonstrated verbal and' 'demonstrated problem solving'
#  'goals demonstrated skills' 'products demonstrated skills'
#  'for demonstrating knowledge' 'demonstrate the use'
#  'demonstrate the tommy' 'demonstrate the operation'
#  'demonstrate the following' 'demonstrated comfort and'
#  'demonstrate full understanding' 'demonstrate willingness to'
#  'demonstrate to customers' 'demonstrated ability in' 'demonstrate use of'
#  'demonstrate training and' 'product knowledge and demonstrate'
#  'representatives demonstrating sales skills'
#  'shop demonstrate knowledge of' 'demonstrate features and benefits'
#  'demonstrate adherence to internal' 'demonstrate eddie bauer style'
#  'demonstrated skills in fundraising' 'demonstrate the use of'
#  'demonstrate the tommy bahama' 'demonstrate the operation of'
#  'demonstrate effective phone etiquette'
#  'demonstrate complete knowledge of' 'demonstrate an established record'
#  'demonstrate commitment to officemax' 'demonstrate behaviours that are'
#  'demonstrate basic selling skills' 'demonstrate and practice the'
#  'demonstrate an understanding of' 'demonstrate an in depth'
#  'demonstrate feasibility of the' 'demonstrate good judgment when'
#  'demonstrate full understanding of' 'demonstrate high degrees of'
#  'demonstrate strong organizational skills'
#  'demonstrate sound judgment and' 'demonstrate how new product'
#  'demonstrate our quality set' 'demonstrate open approachable and'
#  'demonstrate knowledge of merchandise'
#  'demonstrate intermediate to advanced' 'demonstrated skills in selling'
#  'demonstrated skills in written'
#  'demonstrated strong negotiation marketing'
#  'demonstrated child welfare case' 'demonstrated comfort and proficiency'
#  'demonstrated child welfare social' 'demonstrated ability to understand'
#  'demonstrated ability to think' 'demonstrated knowledge of selling'
#  'demonstrated ability to drive' 'demonstrates consistent sales focus'
#  'demonstrates high quality service' 'demonstrates desire to help'
#  'demonstrates customer engagement and'
#  'demonstrates comprehensive understanding of'
#  'demonstrates awareness of store' 'demonstrates awareness of individual'
#  'demonstrates awareness of current' 'demonstrated verbal and written'
#  'demonstrated through our people' 'demonstrates strong customer focus'
#  'demonstrates technical expertise and' 'demonstrates the ability to'
#  'demonstrated ability to build' 'demonstrate use of cosmetics'
#  'demonstrate training and presentation' 'demonstrate to customers using'
#  'demonstrated ability to learn' 'demonstrates understanding of customer'
#  'competencies demonstrated knowledge of'
#  'delivering business results demonstrates'
#  'channels competencies demonstrated knowledge'
#  'demonstrating knowledge of the' 'achieve goals demonstrated skills'
#  'ability to demonstrate an' 'ability to demonstrate good'
#  'ability to demonstrate excellent'
#  'manager demonstrate complete knowledge'
#  'managers demonstrate open approachable'
#  'accountable for demonstrating knowledge' 'for demonstrating knowledge of'
#  'skills knowledge and demonstrated' 'the shop demonstrate knowledge'
#  'knowledge and demonstrate training' 'knowledge and demonstrated ability'
#  'technology products demonstrated skills'
#  'perform infomercial cutlery demonstrations'
#  'performance demonstrate an in' 'identified companies demonstrated skills'
#  'degree or equivalent demonstrable' 'deliver and demonstrate'
#  'deliver and demonstrate ag' 'consistently demonstrating the knowledge'
#  'customer needs demonstrable' 'customer needs demonstrable interpersonal'
#  'consumer durables demonstrated track' 'consumer durables demonstrated'
#  'also demonstrate knowledge of' 'also demonstrate knowledge'
#  'knowledge skills abilities demonstrated' 'license must demonstrate'
#  'license must demonstrate competence' 'commodities demonstrated knowledge'
#  'commodities demonstrated knowledge of' 'competencies demonstrable'
#  'competencies demonstrable customer' 'durables demonstrated'
#  'durables demonstrated track' 'durables demonstrated track record'
#  'electrical commodities demonstrated knowledge'
#  'experience demonstrated selling skills'
#  'interpersonal skills demonstrable'
#  'interpersonal skills demonstrable conflict'
#  'and competencies demonstrable' 'and competencies demonstrable customer'
#  'into teachable moments demonstrates'
#  'excellent typing skills demonstrable' 'fsas demonstrate knowledge'
#  'fsas demonstrate knowledge of' 'equivalent demonstrable record of'
#  'equivalent demonstrable' 'equivalent demonstrable record'
#  'have demonstrated verifiable' 'and demonstrate expert knowledge'
#  'and demonstrate associated skills' 'and demonstrated skill'
#  'must demonstrate the knowledge' 'must also demonstrate knowledge'
#  'needs demonstrable' 'needs demonstrable interpersonal'
#  'needs demonstrable interpersonal skills'
#  'objectives verifiable and demonstrated'
#  'analytical skills demonstrated experience'
#  'knowledge demonstrated ability to' 'knowledge demonstrated'
#  'knowledge demonstrated ability'
#  'experienceknowledge skills abilities demonstrated'
#  'and knowledge demonstrated ability' 'and knowledge demonstrated'
#  'licenses demonstrated' 'licenses demonstrated ability'
#  'licenses demonstrated ability to' 'will demonstrate strong skills'
#  'will demonstrate expert knowledge' 'abilities demonstrated skills'
#  'abilities and competencies demonstrable'
#  'will have demonstrated verifiable'
#  'role demonstrates extensive knowledge'
#  'role demonstrates comprehensive knowledge'
#  'role demonstrates advanced knowledge'
#  'sales demonstrates advanced knowledge'
#  'strongly preferredskills demonstrated knowledge'
#  'teachable moments demonstrates' 'teachable moments demonstrates positive'
#  'performs onsite equipment demonstrations' 'typing skills demonstrable'
#  'typing skills demonstrable understanding'
#  'verifiable and demonstrated skill' 'verifiable and demonstrated'
#  'or equivalent demonstrable' 'or equivalent demonstrable record'
#  'ability previously demonstrated' 'demonstrate safety'
#  'demonstrate product upon' 'demonstrate product upon request'
#  'demonstrate product use' 'demonstrate product use and'
#  'demonstrate products and' 'demonstrate products and services'
#  'demonstrate products explain' 'demonstrate products explain product'
#  'demonstrate products to' 'demonstrate products to customers'
#  'demonstrate professional tone' 'demonstrate professional tone voice'
#  'demonstrate return' 'demonstrate return on'
#  'demonstrate return on investment' 'demonstrate safe'
#  'demonstrate safe practices' 'demonstrate safety commitment'
#  'demonstrate strong skills in' 'demonstrate sound safety'
#  'demonstrate selling' 'demonstrate selling competence'
#  'demonstrate selling competence styling' 'demonstrate sound business'
#  'demonstrate sound business judgment' 'demonstrate sound safety practices'
#  'demonstrate self assurance' 'demonstrate strong active'
#  'demonstrate strong active listening' 'demonstrate strong product'
#  'demonstrate strong product technical' 'demonstrate strong skills'
#  'demonstrate safe practices and' 'demonstrate safety commitment by'
#  'demonstrate strong teamwork' 'demonstrate whatever'
#  'demonstrate the models' 'demonstrate the knowledge skills'
#  'demonstrate the knowledge' 'demonstrate the following qualities'
#  'demonstrate tact' 'demonstrate tact and'
#  'demonstrate tact and sensitivity' 'demonstrate teamwork at'
#  'demonstrate teamwork at all' 'demonstrate teamwork leadership'
#  'demonstrate teamwork leadership and' 'demonstrate whatever it takes'
#  'demonstrate tenacious' 'demonstrate tenacious drive for'
#  'demonstrate to our clients' 'demonstrate to our'
#  'demonstrate the surgical use' 'demonstrate strong teamwork skills'
#  'demonstrate the models spec' 'demonstrate the organizational'
#  'demonstrate the organizational ability' 'demonstrate the surgical'
#  'demonstrate through examples the' 'demonstrate the wirtz'
#  'demonstrate the wirtz ways' 'demonstrate thorough understanding'
#  'demonstrate thorough understanding of' 'demonstrate through'
#  'demonstrate through examples' 'demonstrate self initiative be'
#  'demonstrate self initiative' 'demonstrate self assurance self'
#  'demonstrate whatever it' 'demonstrated ability of responsible'
#  'demonstrated ability to act' 'demonstrated ability to collaborate'
#  'demonstrated ability to communicate' 'demonstrated ability to create'
#  'demonstrated ability to deliver' 'demonstrated ability to establish'
#  'demonstrated alpha and numeric' 'demonstrated analytical and'
#  'demonstrated analytical and problem' 'demonstrated consulting'
#  'demonstrated consulting skills' 'demonstrated consulting skills to'
#  'demonstrated ability of' 'demonstrated ability in problem'
#  'demonstrated ability in organization' 'demonstrated ability with'
#  'demonstrated ability with ibm' 'demonstrated alpha'
#  'demonstrated ability to exercise' 'demonstrated alpha and'
#  'demonstrated ability to execute' 'demonstrate willingness to learn'
#  'demonstrated ability exhibiting effective'
#  'demonstrate willingness to perform' 'demonstrate wireless'
#  'demonstrate wireless products' 'demonstrate wireless products and'
#  'demonstrated ability developing'
#  'demonstrated ability developing complex'
#  'demonstrated ability exhibiting' 'demonstrated by effectively'
#  'demonstrated arithmetic' 'demonstrated arithmetic and'
#  'demonstrate willingness and interest' 'demonstrated arithmetic and word'
#  'demonstrated attention to' 'demonstrated attention to detail'
#  'demonstrated by' 'demonstrated by effectively selling'
#  'demonstrated and continued' 'demonstrated commitment'
#  'demonstrated attention' 'demonstrated knowledge of effective'
#  'demonstrate willingness and' 'demonstrated and continued adherence'
#  'demonstrated and' 'demonstrated interpersonal' 'demonstrated high'
#  'demonstrated high level' 'demonstrated high level of'
#  'demonstrated history' 'demonstrated history of'
#  'demonstrated history of business' 'demonstrated interpersonal skills'
#  'demonstrated analytical skills and'
#  'demonstrated commitment to excellent' 'demonstrated commitment to'
#  'demonstrated analytical communication'
#  'demonstrated analytical communication and'
#  'demonstrated analytical skills' 'demonstrate territory'
#  'demonstrate territory management'
#  'demonstrate territory management skills'
#  'demonstrate the following competencies' 'demonstrate tenacious drive'
#  'ability to demonstrate celgene' 'ability to demonstrate passion'
#  'regulation demonstrates advanced knowledge'
#  'regulation demonstrates working knowledge'
#  'demonstrated ability to utilize' 'demonstrated ability to teach'
#  'demonstrates the values of' 'demonstrates working'
#  'demonstrates working knowledge' 'demonstrates working knowledge of'
#  'demonstrating brand selling skills' 'demonstrating the knowledge'
#  'demonstrating the knowledge skills' 'demonstration skills'
#  'demonstrate excellence in' 'demonstrate excellence in clinical'
#  'demonstrate empathy clarify customer' 'demonstrate empathy clarify'
#  'demonstrate effective selling' 'demonstrate competence'
#  'demonstrate competence working' 'demonstrate competence working in'
#  'demonstrate complex' 'demonstrate complex media'
#  'demonstrate complex media solutions' 'demonstrate concern'
#  'demonstrate concern for' 'demonstrate concern for the'
#  'demonstrate courteous' 'demonstrate courteous and'
#  'demonstrate excellence' 'demonstrate essential core competencies'
#  'demonstrate essential core' 'demonstrate english'
#  'demonstrated knowledge of electrical'
#  'demonstrated interpersonal skills enjoys' 'demonstrate empathy patience'
#  'demonstrate empathy patience and' 'demonstrate empathy while'
#  'demonstrate empathy while maximizing' 'demonstrate english language'
#  'demonstrate essential' 'demonstrate english language proficiency'
#  'demonstrate enthusiasm' 'demonstrate enthusiasm for'
#  'demonstrate enthusiasm for modern' 'demonstrate equipment'
#  'demonstrate equipment connectivity'
#  'demonstrate equipment connectivity and' 'demonstrates the values'
#  'demonstrated knowledge of point' 'demonstrates proficiency in use'
#  'demonstrates skills' 'demonstrates skills in'
#  'demonstrates skills in functional' 'demonstrates strong detail'
#  'demonstrates strong detail orientation' 'demonstrates strong listening'
#  'demonstrates processes or' 'demonstrates personal'
#  'demonstrates personal and' 'demonstrates personal and enthusiastic'
#  'demonstrates positive' 'demonstrates positive attitude'
#  'demonstrates positive attitude with' 'demonstrates processes'
#  'demonstrates processes or activities' 'demonstrates ownership of'
#  'demonstrates product features' 'demonstrates product features and'
#  'demonstrates product technical'
#  'demonstrates product technical expertise' 'demonstrates products and'
#  'demonstrates the value' 'demonstrates the value of'
#  'demonstrates ownership of own' 'demonstrates ownership'
#  'demonstrates strong listening written'
#  'demonstrates teamwork communicates with' 'demonstrates strong selling'
#  'demonstrates strong selling ability' 'demonstrates superior'
#  'demonstrates superior customer' 'demonstrates teamwork'
#  'demonstrates teamwork communicates' 'demonstrates the brand'
#  'demonstrates our commitment to' 'demonstrates the brand values'
#  'demonstrates proficiency in keyboard' 'demonstrates products and or'
#  'demonstrates products' 'demonstrates our' 'demonstrates our commitment'
#  'demonstrate courteous and helpful' 'demonstrate current'
#  'demonstrate current and' 'demonstrate and exhibit'
#  'demonstrate and exhibit high' 'demonstrate and recommend'
#  'demonstrate and recommend so' 'demonstrate associated'
#  'demonstrate associated skills' 'demonstrate associated skills and'
#  'demonstrate bias' 'demonstrate bias for' 'demonstrate bias for action'
#  'demonstrate celgene' 'demonstrate celgene corporate'
#  'demonstrable understanding' 'demonstrable record of consistent'
#  'demonstrable record of' 'demonstrate celgene corporate values'
#  'demonstrate an understanding that' 'demonstrated ability to innovate'
#  'demonstrate an intermediate level' 'demonstrate an added value'
#  'demonstrate passion for extraordinary'
#  'demonstrate problem solving leadership'
#  'demonstrate problem solving skills' 'demonstrated ability to function'
#  'demonstrated ability to implement' 'demonstrated ability to interpret'
#  'demonstrated ability to maintain' 'demonstrated ability to manage'
#  'demonstrated ability to plan' 'demonstrated ability to recognize'
#  'demonstrated ability to solve' 'demonstrate an intermediate'
#  'demonstrate an immediate positive' 'demonstrate an organized thought'
#  'demonstrate ag' 'demonstrate an organized'
#  'demonstrable understanding of' 'demonstrable understanding of the'
#  'demonstrate 12' 'demonstrate 12 36' 'demonstrate 12 36 month'
#  'demonstrate adherence to all' 'demonstrate ag equipment'
#  'demonstrate an immediate' 'demonstrate ag equipment to'
#  'demonstrate passion for advising' 'demonstrate an added'
#  'demonstrate current and working' 'demonstrate mental agility'
#  'demonstrate mental agility identifying' 'demonstrate new vehicles'
#  'demonstrate new vehicles offer' 'demonstrate our expertise'
#  'demonstrate our expertise in' 'demonstrate knowledge of investment'
#  'demonstrate exceptional' 'demonstrate integrity respect and'
#  'demonstrate integrity' 'demonstrate exceptional verbal and'
#  'demonstrate expert knowledge of'
#  'demonstrate expert knowledge pertaining' 'demonstrate expertise'
#  'demonstrate expertise in' 'demonstrate expertise in their'
#  'demonstrate mental' 'demonstrate learning and decision'
#  'demonstrate learning and' 'demonstrate exceptional verbal'
#  'demonstrate customer first perspective'
#  'demonstrate effective selling skills'
#  'demonstrate commitment to teamwork'
#  'demonstrate knowledge of investments' 'demonstrate learning'
#  'demonstrate leadership abilities' 'demonstrate leadership abilities and'
#  'demonstrate leadership collaboration'
#  'demonstrate leadership collaboration with' 'demonstrate leadership in'
#  'demonstrate leadership in your' 'demeanor demonstrated sales skills'
#  'demonstrable conflict' 'demonstrable conflict resolution'
#  'demonstrable conflict resolution and' 'demonstrable customer'
#  'demonstrable interpersonal' 'demonstrable interpersonal skills'
#  'demonstrable interpersonal skills demonstrable' 'demonstrable record'
#  'demonstrate how wwmp' 'demonstrate good judgment and'
#  'demonstrate how to' 'demonstrate how to use'
#  'demonstrate how wwmp technical' 'demonstrate integrity respect'
#  'demonstrate commitment to excellence' 'demonstrates basic functional'
#  'demonstrated time management and' 'demonstrated top'
#  'demonstrated top quartile' 'demonstrated top quartile performance'
#  'demonstrated track record as' 'demonstrated understanding'
#  'demonstrated understanding across'
#  'demonstrated understanding across partner' 'demonstrated verifiable'
#  'demonstrates ability' 'demonstrates ability to'
#  'demonstrates ability to interact' 'demonstrates accuracy'
#  'demonstrates accuracy and' 'demonstrates and fosters'
#  'demonstrates comprehensive knowledge of'
#  'demonstrates commitment to service' 'demonstrates behaviors'
#  'demonstrates behaviors consistent'
#  'demonstrates behaviors consistent with' 'demonstrates collaborative'
#  'demonstrates collaborative interaction'
#  'demonstrates collaborative interaction with'
#  'demonstrates commitment to officemax' 'demonstrates compliance'
#  'demonstrates compliance with' 'demonstrates compliance with all'
#  'demonstrates composure' 'demonstrates composure and'
#  'demonstrates composure and thoughtful'
#  'demonstrates comprehensive knowledge'
#  'demonstrates accuracy and thoroughness' 'demonstrates and'
#  'demonstrates and fosters the' 'demonstrates leadership and the'
#  'demonstrates extensive knowledge and' 'demonstrates extensive knowledge'
#  'demonstrates exceptional selling skills'
#  'demonstrates consultative behaviors'
#  'demonstrates consultative behaviors in' 'demonstrates customer first'
#  'demonstrates leadership' 'demonstrates customer first mindset'
#  'demonstrates essential' 'demonstrates essential abilities'
#  'demonstrates essential abilities including' 'demonstrates ethical'
#  'demonstrates leadership and' 'demonstrates jones lang lasalle'
#  'demonstrated time management' 'demonstrates genuine interest'
#  'demonstrates consultative' 'demonstrates flextronics'
#  'demonstrates flextronics values'
#  'demonstrates flextronics values identifies' 'demonstrates genuine'
#  'demonstrates genuine interest in' 'demonstrates jones lang'
#  'demonstrates high level' 'demonstrates high level of' 'demonstrates how'
#  'demonstrates how technology' 'demonstrates how technology can'
#  'demonstrates jones' 'demonstrates basic functional technical'
#  'demonstrates basic' 'demonstrates ethical and honest'
#  'demonstrates ethical and' 'demonstrates excellent'
#  'demonstrated proficiency to close' 'and tools demonstrated knowledge'
#  'demonstrates logical analysis and' 'demonstrates logical analysis'
#  'demonstrated sales and' 'demonstrated progress towards'
#  'demonstrated progress towards such' 'demonstrated project'
#  'demonstrated project management' 'demonstrated project management skills'
#  'demonstrates logical' 'demonstrated sales and or'
#  'demonstrated results in building' 'demonstrated sales skills'
#  'demonstrated sales skills valid' 'demonstrated selling'
#  'demonstrated selling skills' 'demonstrated selling skills excellent'
#  'demonstrated skill' 'demonstrated skill in' 'demonstrated progress'
#  'demonstrated proficiency to' 'demonstrates excellent listening'
#  'demonstrated proficiency in skills'
#  'demonstrated practices significantly influences' 'demonstrated presence'
#  'demonstrated presence and' 'demonstrated presence and poise'
#  'demonstrated problem solving ability'
#  'demonstrated problem solving skills' 'demonstrated professional'
#  'demonstrated organizational and time'
#  'demonstrated professional reception' 'demonstrated organizational and'
#  'demonstrated oral and' 'demonstrated knowledge to'
#  'demonstrated knowledge to utilize' 'demonstrated leadership ability'
#  'demonstrated leadership across' 'demonstrated leadership across all'
#  'demonstrated practices significantly' 'demonstrated practices'
#  'demonstrated performance to strategically'
#  'demonstrated technical understanding of'
#  'demonstrates excellent listening skills'
#  'demonstrates exceptional customer' 'demonstrates exceptional selling'
#  'demonstrates extensive' 'demonstrated time'
#  'demonstrated organizational planning' 'demonstrated performance to'
#  'demonstrated organizational planning and' 'demonstrated passion'
#  'demonstrated passion for' 'demonstrated passion for customer'
#  'demonstrated performance in' 'demonstrated performance in community'
#  'demonstrated leadership competencies'
#  'demonstrated leadership competencies and'
#  'demonstrated leadership experience' 'demonstrated team'
#  'demonstrated team player' 'demonstrated strong work'
#  'demonstrated team player problem' 'demonstrated technical'
#  'demonstrated technical understanding' 'demonstrated skills in sales'
#  'demonstrated skill in performing' 'demonstrated strong work ethic'
#  'demonstrated strong supervisory skills'
#  'demonstrated leadership experience competitive'
#  'demonstrated maturity self confidence' 'demonstrated leadership skills'
#  'demonstrated leadership skills exceptional' 'demonstrated management'
#  'demonstrated management skills' 'demonstrated management skills to'
#  'demonstrated maturity' 'demonstrated maturity self' 'demonstrated oral'
#  'demonstrated strong supervisory' 'demonstrated oral and written'
#  'demonstrated professional reception and'
#  'demonstrated proficiency in microsoft' 'demonstrated proficiency in one'
#  'demonstrated strong and' 'demonstrated strong and professional'
#  'skills demonstrated knowledge' 'skills demonstrated knowledge of'
#  'skills demonstrated leadership experience'
#  'solutions demonstrated consulting skills'
#  'skills and knowledge demonstrated' 'skills demonstrable conflict'
#  'skills demonstrated experience' 'skills demonstrable understanding of'
#  'skills demonstrable understanding'
#  'service skills demonstrated knowledge'
#  'systems demonstrated interpersonal skills'
#  'solutions fsas demonstrate knowledge'
#  'skills demonstrable conflict resolution'
#  'tools demonstrated knowledge to' 'tools demonstrated knowledge'
#  'premium consumer durables demonstrated'
#  'preferredskills demonstrated knowledge'
#  'preferredskills demonstrated knowledge of' 'ability to demonstrate to'
#  'ability to demonstrate learning'
#  'priorities demonstrated management skills'
#  'prioritize customer needs demonstrable']
# ['communication skills' 'oral communication skills'
#  'and communication skills' 'communication and interpersonal skills'
#  'verbal communication skills' 'and verbal communication skills'
#  'written communication skills' 'and written communication skills'
#  'excellent communication skills' 'strong communication skills'
#  'interpersonal and communication skills' 'required communication skills'
#  'holidays strong communication skills' 'plus communication skills'
#  'experience plus communication skills' 'not required communication skills'
#  'preferred communication skills' 'interpersonal communication skills'
#  'communications skills' 'is required communication skills'
#  'exceptional communication skills' 'communication and presentation skills'
#  'fine jewelry communication skills'
#  'procedures exceptional communication skills'
#  'jewelry communication skills' 'weekends excellent communication skills'
#  'written communications skills' 'and written communications skills'
#  'good communication skills' 'have excellent communication skills'
#  'communication skills computer skills'
#  'qualifications communication skills' 'effective communication skills'
#  'proven communication skills' 'outstanding communication skills'
#  'and communications skills' 'communication skills able'
#  'strong interpersonal communication skills' 'communication skills able to'
#  'effective verbal communication skills'
#  'excellent verbal communication skills'
#  'leadership strong communication skills'
#  'professional communication skills'
#  'punctuality qualifications communication skills'
#  'communication and listening skills'
#  'strong professional communication skills'
#  'possess excellent communication skills'
#  'targets excellent communication skills'
#  'needed qualifications communication skills'
#  'skills outstanding communication skills'
#  'appearance excellent communication skills'
#  'verbal and communication skills' 'in fragrances communication skills'
#  'insurance strong communication skills' 'good communication skills able'
#  'fragrances communication skills' 'manner good communication skills'
#  'excellent communications skills' 'persuasive communication skills'
#  'andverbal communication skills' 'communication interpersonal skills'
#  'great communication skills' 'communication skills proactive adaptable'
#  'communication and negotiation skills'
#  'excellent oral communication skills'
#  'written andverbal communication skills'
#  'with strong communication skills'
#  'experience excellent communication skills'
#  'strong verbal communication skills' 'and persuasive communication skills'
#  'have great communication skills' 'utilize strong communication skills'
#  'english good communication skills' 'ortraining communication skills'
#  'verbal communications skills' 'telephone communication skills'
#  'communications presentation skills' 'communication presentation skills'
#  'communication skills education' 'products excellent communication skills'
#  'required excellent communication skills'
#  'written verbal communication skills'
#  'strong communications presentation skills'
#  'skills verbal communication skills'
#  'preferred strong communication skills'
#  'professional verbal communication skills'
#  'preferred effective communication skills'
#  'preferred excellent communication skills'
#  'trainingrequirements strong communication skills'
#  'verbal written communication skills' 'etc excellent communication skills'
#  'communication skills listening skills' 'communication skills that enable'
#  'communication and analytical skills'
#  'communication preferredbasic computer skills'
#  'communications skills be able' 'communication skills past experience'
#  'and ortraining communication skills'
#  'management excellent communication skills'
#  'modeling strong communication skills' 'and verbal communications skills'
#  'appearance and communications skills' 'asset strong communication skills'
#  'acumen excellent communication skills'
#  'and effective communication skills'
#  'abilities excellent communication skills'
#  'and strong communication skills' 'leadership and communication skills'
#  'interpersonal and communications skills'
#  'ged strong communication skills' 'skills effective communication skills'
#  'oriented excellent communications skills'
#  'have strong communication skills' 'have good communication skills'
#  'decision maker communication skills'
#  'competitor websites communication skills'
#  'attitude effective communication skills'
#  'basic strong communication skills'
#  'creative exceptional communication skills'
#  'courteous communication skills' 'conversation and communication skills'
#  'language communication skills' 'communications and interpersonal skills'
#  'communication listening skills' 'communication excellent computer skills'
#  'communication demonstration skills'
#  'communication skills working knowledge' 'communication skills skills'
#  'communication skills analytical skills'
#  'communication organizational skills'
#  'communication organizational skills experience'
#  'communication skills education and' 'communication skills skill'
#  'communication skills education bachelor'
#  'communication skills interpersonal skills'
#  'communication skills negotiation skills'
#  'communication skills preferred education'
#  'communication and conversation skills'
#  'communication and leadership skills'
#  'communication and managerial skills'
#  'communication and organization skills' 'communication and people skills'
#  'communication and writing skills'
#  'communications desirable skills ability'
#  'communications desirable skills' 'competition communication skills'
#  'company communications knowledge skills'
#  'competencies strong communication skills'
#  'communications knowledge skills' 'communications knowledge skills and'
#  'communications organizational skills' 'communications skills experience'
#  'communications strong relationship skills'
#  'class excellent communication skills'
#  'development and communication skills' 'electronic communication skills'
#  'effective communication skills skill'
#  'assistance stellar communication skills' 'bilingual communication skills'
#  'excellent communication skills education'
#  'experience outstanding communication skills'
#  'interpersonal communication presentation skills'
#  'interpersonal communications skills'
#  'and communications skills experience'
#  'interaction strong communication skills' 'ethic and communication skills'
#  'excellent written communication skills'
#  'instructions fluent communication skills'
#  'excellent telephone communication skills'
#  'funds excellent communication skills'
#  'goals excellent communication skills'
#  'goals outstanding communication skills'
#  'equivalent excellent communication skills'
#  'equivalency communication skills' 'and excellent communication skills'
#  'industry excellent communication skills'
#  'include exceptional communication skills'
#  'including excellent communication skills'
#  'is needed communication skills' 'and electronic communication skills'
#  'needs solid communications skills' 'needed communication skills'
#  'of communication skills' 'advanced communication presentation skills'
#  'motivational and communication skills'
#  'advantage good communication skills'
#  'advanced verbal communication skills'
#  'management strong communication skills'
#  'management and communication skills'
#  'fields excellent communication skills' 'fluent communication skills'
#  'maker communication skills' 'websites communication skills'
#  'abilities strong communication skills'
#  'weight required communication skills'
#  'outlook outstanding communication skills'
#  'others excellent communication skills'
#  'outstanding communications skills'
#  'outstanding verbal communication skills' 'whose communication skills'
#  'task good communication skills'
#  'requirements communication demonstration skills'
#  'people and communication skills' 'with exceptional communication skills'
#  'strong phone communication skills'
#  'requirements strong communication skills' 'two way communication skills'
#  'person whose communication skills' 'phone communication skills'
#  'plus excellent communications skills' 'way communication skills'
#  'values excellent communication skills'
#  'ability effective communication skills'
#  'verbal written communications skills'
#  'verbal interpersonal communications skills'
#  'verbal communication skills able' 'verbal communication skills education'
#  'verbal communications desirable skills'
#  'verbal communication interpersonal skills'
#  'verbal communication skills skills' 'verbal and communications skills'
#  'organization and communication skills'
#  'organization strong communication skills'
#  'orientation and communication skills'
#  'organizational communication interpersonal skills'
#  'office and communication skills' 'of team communication skills'
#  'oral communication organizational skills'
#  'wpm excellent communication skills' 'writing and communications skills'
#  'written communication skills able' 'or equivalency communication skills'
#  'use written communication skills'
#  'written communications organizational skills'
#  'written oral communication skills' 'writing strong communication skills'
#  'the competition communication skills'
#  'and telephone communication skills' 'stellar communication skills'
#  'sales strong communication skills' 'skills good communication skills'
#  'skills exceptional communication skills'
#  'skills excellent communication skills' 'range of communication skills'
#  'service bilingual communication skills'
#  'spanish language communication skills'
#  'strong communication interpersonal skills'
#  'required courteous communication skills'
#  'strong communication listening skills'
#  'required good communication skills' 'solid communications skills'
#  'skills communication skills' 'possesses excellent communication skills'
#  'presence exceptional communication skills'
#  'quotas exceptional communication skills'
#  'prioritization and communication skills'
#  'process strong communication skills' 'team communication skills'
#  'selling skills communication skills'
#  'timeframes strong communication skills'
#  'products outstanding communications skills']
# ['combination of qualifying experience' 'combined with experience'
#  'or combined with experience' 'reliable working condition combination'
#  'delivering the combined' 'delivering the combined power'
#  'combined experience' 'combination of experience'
#  'combined with related experience' 'equivalent combination of experience'
#  'performance by combining' 'performance by combining advanced'
#  'years combined experience' 'of years combined experience']
# ['ability to communicate' 'ability to communicate this'
#  'ability to communicate both' 'ability to communicate clearly'
#  'ability to communicate fluently'
#  'communication maintain comprehensive knowledge'
#  'knowledge maintain constant communication' 'ability to communicate and'
#  'ability to communicate verbally' 'preferable excellent communication'
#  'salesforce preferable excellent communication'
#  'preferable excellent communication and'
#  'transportationknowledge of wireless communication'
#  'communication preferred working knowledge' 'ability to communicate them'
#  'ability to communicate well' 'data communications high knowledge'
#  'date knowledge of communications' 'communications desirable'
#  'communication job knowledge' 'communicates knowledge'
#  'communicates knowledge on' 'communicates knowledge on industry'
#  'communicating competitive knowledge'
#  'communicating competitive knowledge and' 'communications high knowledge'
#  'company communications knowledge' 'communications high knowledge of'
#  'communications knowledge' 'comfortable communicating at all'
#  'comfortable communicating' 'comfortable communicating at'
#  'business knowledge collaboration communication'
#  'be comfortable communicating at' 'be comfortable communicating'
#  'and company communications knowledge' 'and communicates knowledge on'
#  'and communicates knowledge' 'into actionable insights communicate'
#  'increase knowledge communicated'
#  'increase knowledge communicated effectively'
#  'must be comfortable communicating'
#  'knowledge collaboration communication customer'
#  'knowledge collaboration communication'
#  'knowledge communication and interpersonal' 'knowledge communicated'
#  'knowledge communicated effectively'
#  'knowledge communicated effectively with' 'knowledge communication'
#  'knowledge communication and' 'knowledge of communications'
#  'knowledge of communications trends'
#  'perform special projects communicate'
#  'retailers and communicates knowledge' 'performance communicates'
#  'performance communicates desire' 'performance communicates desire to'
#  'performance communicate' 'performance communicate effectively'
#  'performance communicate effectively with'
#  'performance culture strong communication'
#  'ability effective communication' 'verbal communication job knowledge'
#  'verbal communications desirable'
#  'actionable insights communicate initiative'
#  'actionable insights communicate' 'performed develop communication'
#  'performed develop communication with'
#  'ability to communicate professionally' 'ability to communicate on'
#  'ability to communicate the' 'ability to communicate correctly'
#  'ability to communicate review' 'and verbal communications desirable'
#  'to increase knowledge communicated' 'product knowledge communication'
#  'product knowledge communication and'
#  'products communicating competitive knowledge'
#  'through product knowledge communication' 'ability to communicate by'
#  'ability to communicate conclusions' 'ability to communicate business']
# ['knowledge of' 'knowledge and' 'product knowledge' ...,
#  'professionals have knowledge to' 'professionals have knowledge'
#  'professional with strong knowledge']
# ['experience preferred communication skills' 'preferred experience'
#  'experience preferred experience' 'preferred retail selling experience'
#  'sales experience preferred experience' 'degree preferred experience'
#  'preferred customer service experience'
#  'preferred prior retail experience' 'experience preferred knowledge of'
#  'preferred prior sales experience' 'experience preferred knowledge'
#  'preferably with experience' 'equivalent preferred experience'
#  'preferred years experience' 'preferred related experience'
#  'preferred required experience' 'ged equivalent preferred experience'
#  'preferred two years experience' 'preferred previous retail experience'
#  'technology preferably with experience' 'preferably experience'
#  'environment preferably experience' 'preferred skills experience'
#  'experience preferred skills' 'retail experience preferred experience'
#  'service environment preferably experience'
#  'years experience preferred experience' 'preferred years sales experience'
#  'preference given to experience' 'preferred must have experience'
#  'preferred retail apparel experience' 'degree preferred radio experience'
#  'degree preferred related experience'
#  'certified preferred healthcare experience'
#  'chemistries preferred sap experience'
#  'chromatography equipment preferred experience'
#  'bachelors degree preferred experience'
#  'coursework preferred required experience'
#  'knowledge preferably with experience'
#  'certification experience preferred'
#  'certification experience preferred other'
#  'college preferred related experience'
#  'college preferred years experience' 'business preferred experience'
#  'distribution preferred experience' 'experience preferred selling skills'
#  'experience preferred skills experience'
#  'experience preferred timeshare experience'
#  'experience preferred urological experience'
#  'experience preferred working knowledge'
#  'experience preferred demonstrated experience'
#  'experience preferred multifamily affordable'
#  'experience preferred business knowledge'
#  'experience preferable automotive'
#  'experience preferable automotive sales' 'experience preferable'
#  'ged preferred experience' 'and experience preferred knowledge'
#  'equivalent experience preferable'
#  'equivalent experience preferable automotive'
#  'equivalent preferred related experience' 'equipment preferred experience'
#  'environments preferred experience'
#  'environments preferred experience experience'
#  'graduate preferred years experience' 'highly preferred years experience'
#  'highly preferred experience' 'history major preferred experience'
#  'is preferred required experience' 'is preferred requires experience'
#  'analysis experience preferred knowledge'
#  'manufacturing business preferred experience'
#  'managerial experience preferred experience'
#  'management certification experience preferred'
#  'management preferred qualifications experience'
#  'experience yrs preferred qualificationsskills'
# ...
#  'variable organization wyndham vacation' 'variable organization wyndham'
#  'organization desired certificates' 'organization capabilities able'
#  'organization capabilities able to' 'organization capable'
#  'organization capable of' 'organization capable of handling'
#  'acknowledgement organization' 'acknowledgement organization establishing'
#  'acknowledgement organization establishing courses'
#  'deliver strategic change organization' 'schedule variable organization'
#  'schedule variable organization wyndham' 'ability to learn organization'
#  'time schedule variable organization']
# ['customer service skills' 'customer service experience'
#  'deliver exceptional service' 'deliver excellent customer service'
#  'demonstrate excellent customer service' 'customer service by educating'
#  'service by educating customers' 'service by educating'
#  'delivering superior service' 'delivering customer service'
#  'delivering customer service that' 'deliver these services'
#  'or customer service experience' 'delivering exceptional customer service'
#  'deliver service like no' 'deliver service' 'deliver service like'
#  'delivering superior service retail'
#  'deliver unparalleled customer service' 'demonstrated customer service'
#  'demonstrated customer service skills' 'services educate'
#  'services educate and' 'and services educate'
#  'remarkable customer service' 'customer services skills'
#  'service honorable' 'superior customer services skills'
#  'overall customer service experience' 'customer service knowledge'
#  'customer service knowledge of' 'approachable drives customer service'
#  'courteous customer service knowledge'
#  'demonstratestrong customer focused service'
#  'delivered legandary customer service' 'effective customer service skills'
#  'face customer service experience' 'great customer service skills'
#  'deliver the service' 'service post secondary education'
#  'demonstrates customer service as' 'deliver the service and'
#  'deliver outstanding guest service' 'demonstrates customer service'
#  'reliable home services' 'customer acknowledge customers'
#  'the service honorable' 'service honorable discharge'
#  'of service honorable' 'service honorable discharge the'
#  'prior customer service experience' 'character of service honorable'
#  'of the service honorable' 'demonstrate strong customer service'
#  'deliver outstanding customer service'
#  'customer service retail experience' 'the service honorable discharge'
#  'the customer acknowledge customers' 'reliable home services for'
#  'consistent reliable home services' 'knowledge and customer service'
#  'customer acknowledge customers in' 'renewable service' 'delivers service'
#  'service knowledgeplanning' 'service education' 'enable the services'
#  'renewable service agreements' 'and service knowledgeplanning'
#  'education and services' 'educate and service' 'service honorable general'
#  'service knowledgeplanning and' 'deliver supreme service'
#  'delivers service within' 'delivers products services'
#  'delivers exceptional service' 'expands renewable service'
#  'profitable treasury services' 'delivering excellent service'
#  'renewable service agreements to' 'service honorable general etc'
#  'service free continuing education' 'service retail field stable'
#  'services available guide customers' 'your customer service skills'
#  'product and service knowledgeplanning' 'customer service abilities able'
#  'customer service be able' 'customer service relations skills'
#  'customer service standards accountable' 'enable the services business'
#  'expands renewable service agreements'
#  'develops profitable treasury services' 'delivers service within the'
#  'delivers products services systems' 'deliver supreme service using'
#  'delivering excellent service to'
#  'delivering customer service consistently'
#  'deliver professional customer service' 'education and services for'
#  'educate and service team' 'delivers exceptional service and'
#  'delivers exceptional customer service'
#  'months customer service experience' 'and service knowledgeplanning and'
#  'adoption education and services' 'as educate and service'
#  'and expands renewable service' 'is customer service experience'
#  'that enable the services' 'of service honorable general'
#  'conducting in services educational' 'customer service or experience'
#  'customer service oriented knowledge' 'customer service preferred skills'
#  'customer service product knowledge' 'customer service skills capable'
#  'customer service skills knowledge' 'customer service skillseoe disabled'
#  'customer service standard capable' 'customer service able to'
#  'customer service able' 'customer service education center'
#  'customer service education' 'customer service and knowledge'
#  'customer service clienteling skills'
#  'contacting customer service education' 'compensable service'
#  'compensable service connected' 'compensable service connected disability'
#  'competencies demonstrable customer service'
#  'and service features educating' 'and service education to'
#  'and service education' 'and reliable service you' 'and reliable service'
#  'education and career services' 'and services including variable'
#  'and services education professional' 'and services education'
#  'and services to ascertain' 'best service possibleeducation'
#  'best service possibleeducation and' 'excellent customer service able'
#  'excellent customer service experience'
#  'excellent customer services skills'
#  'equivalent customer service experience' 'have compensable service'
#  'have compensable service connected' 'in services educational'
#  'in services educational events' 'music service live concerts'
#  'of customer service experience' 'managed services offering enables'
#  'expert customer service experience' 'performance and customer service'
#  'outstanding customer service experience' 'on customer service skills'
#  'perform fishing services including' 'perform fishing services'
#  'who have compensable service' 'perform onsite service'
#  'perform onsite service installations' 'reliable products and services'
#  'reliable service you will' 'reliable service you' 'reliable service'
#  'patient services educates' 'patient services educates patients'
#  'retail customer service experience' 'performs services in the'
#  'performs services in' 'performs services' 'personal and reliable service'
#  'valuable service to customers' 'performance quality service and'
#  'performance quality service' 'of service honorable to'
#  'yrs customer service experience' 'of service educate sample'
#  'of service educate' 'ability exceptional customer service'
#  'performing services' 'performing services upgrades'
#  'performing services upgrades to' 'the best service possibleeducation'
#  'profitable wholesale services' 'profitable wholesale services and'
#  'demonstrated customer service experience'
#  'quality customer service skills' 'deliver superior customer service'
#  'deliver euo services' 'deliver exemplary customer service'
#  'deliver euo services in' 'deliver product and service'
#  'delivering friendly courteous service' 'delivering great service'
#  'delivering great service to' 'delivering competitively priced services'
#  'delivering excellent customer service'
#  'delivering differentiated sales service'
#  'delivering customer service previous' 'deliver first class service'
#  'delivering outstanding customer service' 'delivering outstanding service'
#  'delivering outstanding service the' 'delivering services'
#  'delivering services and' 'delivering services and documentation'
#  'delivers customer service' 'delivers customer service to'
#  'delivers outstanding customer service'
#  'demonstrates superior customer service' 'demonstrable customer service'
#  'demonstrable customer service and'
#  'demonstrates exceptional customer service'
#  'services available to customers' 'services including variable fixed'
#  'services offering enables' 'services responsibilities include educating'
#  'services offering enables our' 'services including variable'
#  'services educates' 'services educates patients'
#  'services educates patients about' 'service skillseoe disabled'
#  'service skillseoe disabled veteranapply' 'service standard capable'
#  'service standard capable to' 'services education'
#  'steps of service educate' 'services education professional'
#  'service features educating and' 'service education center for'
#  'service education center' 'service educate sample and'
#  'service features educating' 'service education to'
#  'services education professional certifications' 'services educational'
#  'services educational events' 'services educational events value'
#  'service education to facilitate' 'service environment is desirable'
#  'service deliver helpful knowledgeable' 'service possibleeducation and'
#  'service possibleeducation' 'service live concerts'
#  'service live concerts and' 'service desk while educating'
#  'service possibleeducation and qualificationsminimum' 'service educate'
#  'service educate sample' 'service honorable to'
#  'service honorable to determine' 'services to ascertain'
#  'services to ascertain customer' 'to patient services educates'
#  'product and service education' 'selling profitable wholesale services'
#  'products and services education']
# ['available for' 'available for this' 'available for this position' ...,
#  'products are available for' 'procedures that are available'
#  'professional toronto opportunity available']
# ['regular dependable' 'regular dependable attendance'
#  'dependable attendance' 'dependable attendance punctuality'
#  'dependable attendance and' 'and seminars regular dependable'
#  'seminars regular dependable' 'seminars regular dependable attendance'
#  'procedures regular dependable' 'supervisor regular dependable'
#  'pos procedures regular dependable' 'sales regular dependable attendance'
#  'sales regular dependable' 'and sales regular dependable'
#  'stock regular dependable' 'needed regular dependable'
#  'needed regular dependable attendance' 'as needed regular dependable'
#  'dependable vehicle' 'territory possess dependable'
#  'possess dependable vehicle' 'dependable vehicle valid'
#  'possess dependable' 'established territory possess dependable'
#  'results regular dependable' 'sales results regular dependable'
#  'results regular dependable attendance' 'be dependable' 'dependable and'
#  'maximize sales regular dependable' 'dependable and committed'
#  'must be dependable' 'be dependable and' 'must be dependable and'
#  'and procedures regular dependable'
#  'designated territory possess dependable' 'be dependable and committed'
#  'dependable and committed to' 'independently dependable' 'dependable with'
#  'dependable with proficient' 'independently dependable with'
#  'presence regular dependable' 'as independently dependable'
#  'well as independently dependable'
#  'presence regular dependable attendance'
#  'compliance procedures regular dependable'
#  'dependable with proficient attention'
#  'dependable attendance and punctualityqualifications'
#  'as independently dependable with'
#  'independently dependable with proficient'
#  'floor presence regular dependable' 'competitive detailed dependable'
#  'competitive detailed dependable team' 'detailed dependable'
#  'detailed dependable team' 'detailed dependable team player'
#  'email and internet dependable' 'are competitive detailed dependable'
#  'are dependable company' 'are dependable' 'are dependable company job'
#  'assigned regular dependable' 'assigned regular dependable attendance'
#  'being dependable' 'being dependable and'
#  'being dependable and trustworthy' 'be dependable goal'
#  'be dependable goal driven' 'as assigned regular dependable'
#  'internet dependable resourceful self' 'internet dependable'
#  'internet dependable resourceful' 'ethic be dependable'
#  'ethic be dependable goal' 'and housekeeping regular dependable'
#  'environment regular dependable attendance'
#  'environment regular dependable' 'have dependable vehicle with'
#  'have dependable vehicle' 'have dependable'
#  'housekeeping regular dependable'
#  'housekeeping regular dependable attendance' 'and dependable'
#  'and dependable work' 'and dependable work ethic'
#  'is negotiable depending on' 'is negotiable depending'
#  'inventory process regular dependable' 'must have dependable'
#  'must have dependable vehicle' 'of being dependable'
#  'of being dependable and' 'merchandise regular dependable'
#  'merchandise regular dependable attendance' 'extremely dependable'
#  'extremely dependable open' 'extremely dependable open to'
#  'and internet dependable' 'and is negotiable depending'
#  'and internet dependable resourceful' 'negotiable depending on market'
#  'negotiable depending on' 'negotiable depending'
#  'new merchandise regular dependable' 'well with others dependable'
#  'others dependable' 'outrageously dependable'
#  'outrageously dependable service' 'outrageously dependable service to'
#  'others dependable accurate' 'others dependable accurate self'
#  'work ethic be dependable' 'reliable and dependable'
#  'reliable and dependable work' 'with others dependable accurate'
#  'with others dependable' 'trait of being dependable'
#  'we are dependable company' 'we are dependable'
#  'provide outrageously dependable'
#  'provide outrageously dependable service'
#  'regular dependable attendance punctualityqualificationseducation'
#  'dependable accurate' 'dependable accurate self'
#  'dependable accurate self motivated' 'dependable team player that'
#  'dependable vehicle with' 'dependable vehicle with valid'
#  'dependable work' 'dependable work ethic' 'dependable work ethic solid'
#  'dependable team player' 'dependable service' 'dependable service to all'
#  'dependable resourceful self' 'dependable resourceful self motivated'
#  'dependable resourceful'
#  'dependable attendance punctualityqualificationseducation experience'
#  'dependable team' 'dependable service to' 'dependable and trustworthy'
#  'dependable and trustworthy safety'
#  'dependable attendance punctualityqualificationseducation'
#  'dependable company' 'dependable open to new' 'dependable company job'
#  'dependable company job duties' 'dependable goal' 'dependable goal driven'
#  'dependable goal driven have' 'dependable open' 'dependable open to'
#  'skills extremely dependable' 'skills extremely dependable open'
#  'store environment regular dependable'
#  'situations reliable and dependable' 'so we are dependable'
#  'to provide outrageously dependable' 'process regular dependable'
#  'process regular dependable attendance']
# ['demonstrated success' 'demonstrated success working'
#  'perform this job successfully' 'demonstrated success in'
#  'demonstrated successful' 'demonstrated successful sales'
#  'demonstrated successful sales track' 'successfully reasonable'
#  'demonstrates success' 'duties successfully reasonable'
#  'demonstrates success in' 'successfully reasonable accommodations'
#  'performance and success' 'successfully reasonable accommodations may'
#  'demonstrated ability to successfully' 'demonstrates success in selling'
#  'duties successfully reasonable accommodations'
#  'ability to successfully perform' 'these duties successfully reasonable'
#  'perform these duties successfully'
#  'license required demonstrated success' 'enable the success'
#  'enable the success of' 'have demonstrated verifiable success'
#  'delivers successful' 'perform their job successfully'
#  'performance and success by' 'performance and success fostering'
#  'perform the job successfully' 'delivers successful brand'
#  'success measurable track record' 'success measurable track'
#  'success measurable' 'successful origination of viable'
#  'verifiable success in' 'verifiable success'
#  'verifiable success in working'
#  'ability previously demonstrated successful'
#  'proven sales success measurable' 'that enable the success'
#  'deliver the successful' 'deliver the successful candidate'
#  'demonstrated verifiable success' 'demonstrated verifiable success in'
#  'demonstrated success in both' 'demonstrated success in commission'
#  'demonstrated success in direct' 'demonstrated success in exceeding'
#  'demonstrated success in highly' 'demonstrated success in team'
#  'sales success measurable track' 'sales success measurable']

# %%
key=5
words = BagofWords(d[key])
print len(d[key])
print words
# Out:
# 82
# [('knowledge', 38), ('communicate', 24), ('communication', 22), ('to', 19), ('ability', 18), ('communications', 12), ('and', 11), ('communicating', 9), ('communicates', 9), ('performance', 7), ('comfortable', 6), ('communicated', 6), ('effectively', 5), ('of', 5), ('on', 4), ('verbal', 3), ('desirable', 3), ('product', 3), ('competitive', 3), ('high', 3), ('at', 3), ('increase', 3), ('preferable', 3), ('collaboration', 3), ('be', 3), ('with', 3), ('excellent', 3), ('insights', 3), ('actionable', 3), ('develop', 2), ('business', 2), ('company', 2), ('job', 2), ('maintain', 2), ('desire', 2), ('performed', 2), ('all', 1), ('constant', 1), ('into', 1), ('trends', 1), ('interpersonal', 1), ('initiative', 1), ('clearly', 1), ('special', 1), ('strong', 1), ('working', 1), ('conclusions', 1), ('perform', 1), ('transportationknowledge', 1), ('review', 1), ('verbally', 1), ('correctly', 1), ('must', 1), ('them', 1), ('through', 1), ('comprehensive', 1), ('preferred', 1), ('wireless', 1), ('date', 1), ('fluently', 1), ('data', 1), ('by', 1), ('projects', 1), ('customer', 1), ('both', 1), ('salesforce', 1), ('effective', 1), ('culture', 1), ('this', 1), ('well', 1), ('professionally', 1), ('products', 1), ('retailers', 1), ('the', 1), ('industry', 1)]

# %%
len(d[7])
# Out:
# 171

# %%
words
# Out:
# [('related', 138),
#  ('experience', 124),
#  ('years', 16),
#  ('or', 15),
#  ('relations', 15),
#  ('relative', 14),
#  ('of', 14),
#  ('sales', 14),
#  ('skills', 11),
#  ('work', 11),
#  ('other', 11),
#  ('field', 10),
#  ('to', 9),
#  ('perform', 9),
#  ('equivalent', 8),
#  ('education', 8),
#  ('preferred', 6),
#  ('reasonable', 6),
#  ('experienceknowledge', 6),
#  ('ability', 6),
#  ('certifications', 6),
#  ('months', 6),
#  ('customer', 6),
#  ('and', 6),
#  ('license', 5),
#  ('year', 4),
#  ('degree', 4),
#  ('job', 4),
#  ('industry', 4),
#  ('retail', 4),
#  ('relate', 4),
#  ('duties', 4),
#  ('fields', 3),
#  ('for', 3),
#  ('directly', 3),
#  ('service', 3),
#  ('degreejob', 3),
#  ('professional', 3),
#  ('sporting', 2),
#  ('previous', 2),
#  ('requiredemployee', 2),
#  ('underwriting', 2),
#  ('month', 2),
#  ('courses', 2),
#  ('banking', 2),
#  ('public', 2),
#  ('bachelor', 2),
#  ('hospitality', 2),
#  ('previously', 2),
#  ('functional', 2),
#  ('with', 2),
#  ('engineering', 2),
#  ('ap', 2),
#  ('as', 2),
#  ('technology', 2),
#  ('any', 2),
#  ('driver', 2),
#  ('client', 2),
#  ('all', 1),
#  ('outdoor', 1),
#  ('four', 1),
#  ('abilities', 1),
#  ('estimating', 1),
#  ('administrative', 1),
#  ('achieve', 1),
#  ('activities', 1),
#  ('combination', 1),
#  ('they', 1),
#  ('areas', 1),
#  ('performing', 1),
#  ('direct', 1),
#  ('college', 1),
#  ('our', 1),
#  ('investment', 1),
#  ('three', 1),
#  ('strong', 1),
#  ('on', 1),
#  ('etc', 1),
#  ('plus', 1),
#  ('one', 1),
#  ('spanish', 1),
#  ('least', 1),
#  ('registration', 1),
#  ('additional', 1),
#  ('two', 1),
#  ('clinical', 1),
#  ('combined', 1),
#  ('more', 1),
#  ('language', 1),
#  ('resources', 1),
#  ('timeshare', 1),
#  ('is', 1),
#  ('proven', 1),
#  ('in', 1),
#  ('functions', 1),
#  ('prior', 1),
#  ('granted', 1),
#  ('six', 1),
#  ('description', 1),
#  ('effective', 1),
#  ('face', 1),
#  ('requires', 1),
#  ('preferredbranded', 1)]

# %%
skills.sort('cluster',ascending=False).to_csv("./candidate_features_cluster.tsv", encoding='utf8', index=False, sep='\t')

# %%
cluster_type={}

# %%
cluster_type[34] = 'previous experience'

# %%
cluster_type[33] = 'dependable'

# %%
cluster_type[32] = 'unknown'

# %%
cluster_type[31] = 'customer service'

# %%
cluster_type[30] = 'unknown'

# %%
cluster_type[29] = 'unknown'

# %%
cluster_type[28] = 'unknown'

# %%
cluster_type[27] = 'computer skills'

# %%
cluster_type[26] = 'unknown'

# %%
cluster_type[25] = 'skills'

# %%
cluster_type[24] = 'unknown'

# %%
cluster_type[23] = 'license'

# %%
cluster_type[22] = 'drivers license'

# %%
cluster_type[21] = 'previous experience'

# %%
cluster_type[20] = 'merchandise'

# %%
cluster_type[19] = 'delivery'

# %%
cluster_type[18] = 'education experience'

# %%
cluster_type[17] = 'accountable and accounts'

# %%
cluster_type[16] = 'sales experience'

# %%
cluster_type[15] = 'unknown'

# %%
cluster_type[14] = 'unknown'

# %%
cluster_type[13] = 'tables/microsoft/cleaning'

# %%
cluster_type[12] = 'disabled veterans & minorities'

# %%
cluster_type[11] = 'unknown'
cluster_type[10] = 'required years of experience'

# %%
cluster_type[9] = 'unknown/able'

# %%
cluster_type[8] = 'unknown/ability'

# %%
cluster_type[7] = 'previous experience'

# %%
cluster_type[6] = 'knowledge'

# %%
cluster_type[5] = 'communication'

# %%
cluster_type[4] = 'unknown'

# %%
cluster_type[3] = 'communication'

# %%
cluster_type[2] = 'unknown'
cluster_type[1] = 'education'
cluster_type[0] = 'truly unknown'

# %%
len(skills.feature)
# Out:
# 32566

# %%
CT = pd.DataFrame.from_dict(cluster_type,orient='index')

# %%
CT = CT.reset_index()

# %%
CT.columns = ['cluster','type']

# %%
CT
# Out:
#     cluster                            type
# 0         0                   truly unknown
# 1         1                       education
# 2         2                         unknown
# 3         3                   communication
# 4         4                         unknown
# 5         5                   communication
# 6         6                       knowledge
# 7         7             previous experience
# 8         8                 unknown/ability
# 9         9                    unknown/able
# 10       10    required years of experience
# 11       11                         unknown
# 12       12  disabled veterans & minorities
# 13       13       tables/microsoft/cleaning
# 14       14                         unknown
# 15       15                         unknown
# 16       16                sales experience
# 17       17        accountable and accounts
# 18       18            education experience
# 19       19                        delivery
# 20       20                     merchandise
# 21       21             previous experience
# 22       22                 drivers license
# 23       23                         license
# 24       24                         unknown
# 25       25                          skills
# 26       26                         unknown
# 27       27                 computer skills
# 28       28                         unknown
# 29       29                         unknown
# 30       30                         unknown
# 31       31                customer service
# 32       32                         unknown
# 33       33                      dependable
# 34       34             previous experience

# %%
new_skills = skills.merge(CT)

# %%
new_skills.sort('cluster',ascending=False).to_csv("./candidate_features_cluster.tsv", encoding='utf8', index=False, sep='\t')
